# %%
import numpy as np
import pandas as pd 
import os 
import random
import pickle
import warnings
warnings.filterwarnings(action='ignore')

from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.eda.auto as auto

# %%
TRAIN_PATH = "playground-series-s3e10/train.csv"
TEST_PATH = "playground-series-s3e10/test.csv"
SAMPLE_SUBISSION_PATH = "playground-series-s3e10/sample_submission.csv"
SUBMISSION_PATH = "submission.csv"
TARGET = "Class"
NEGATIVE_FEATURES = "negative_features"


SEED = 2022
def seed_everything(seed=SEED):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything()

MODEL_TIME_LIMIT = 60*60
MODEL_SAVE_PATH = "autogluon_model_2/"
MODEL_VERBOSE = 2
MODEL_PRESETS = "best_quality"

NUM_BAG_FOLDS = 5
NUM_BAG_SETS = 1
NUM_STACK_LEVELS = 1

# %%
# try1 keep all features
negative_features_list = ["id"] #["id", "Skewness_DMSNR_Curve"]
# try2 : remove all negative features
negative_features_list = ["id", "Mean_Integrated", "Mean_DMSNR_Curve", "Skewness"]

# %%
train_data = pd.read_csv(TRAIN_PATH).drop(negative_features_list, axis=1)

test_data_all = pd.read_csv(TEST_PATH)
test_data = test_data_all.drop(negative_features_list, axis=1)
test_data_id = test_data_all["id"]

# %%
# pre-made feature generator
from autogluon.features.generators import AutoMLPipelineFeatureGenerator

# This is the default feature generator of AutoGluon, and contains many stages of preprocessing made to handle many types of data.
# AutoMLPipelineFeatureGenerator is an implementation of PipelineFeatureGenerator
# For most users, this should be all they need to get high quality features that are ready to fit models.
auto_ml_pipeline_feature_generator = AutoMLPipelineFeatureGenerator()

train_data_features = train_data.drop(columns=[TARGET])
train_data_features_transform = auto_ml_pipeline_feature_generator.fit_transform(X=train_data_features)
#print(train_data_features_transform.head(5))

# test_data don't have TARGET column
#test_data_features = test_data.drop(columns=[TARGET])
test_data_transform = auto_ml_pipeline_feature_generator.transform(X=test_data)
#print(test_data_transform.head(5))

# %%
train_data_features_transform[TARGET] = train_data[TARGET]

# %%
train_data_features_transform.shape
# Out:
# (117564, 6)

# %%
predictor = TabularPredictor(
    label=TARGET, 
    problem_type="regression", # switch from binary to regression
    path=MODEL_SAVE_PATH, 
    sample_weight="auto_weight", 
    verbosity=MODEL_VERBOSE).fit(
    train_data_features_transform, 
    presets=MODEL_PRESETS, 
    time_limit=MODEL_TIME_LIMIT,
    num_bag_folds=NUM_BAG_FOLDS, 
    num_bag_sets=NUM_BAG_SETS, 
    num_stack_levels=NUM_STACK_LEVELS
)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "autogluon_model_2/"
# AutoGluon Version:  0.6.3b20230205
# Python Version:     3.9.0
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #161-Ubuntu SMP Fri Feb 3 14:49:04 UTC 2023
# Train Data Rows:    117564
# Train Data Columns: 5
# Label Column: Class
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    41767.47 MB
# 	Train Data (Original)  Memory Usage: 4.7 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 5 | ['SD', 'EK', 'SD_DMSNR_Curve', 'EK_DMSNR_Curve', 'Skewness_DMSNR_Curve']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 5 | ['SD', 'EK', 'SD_DMSNR_Curve', 'EK_DMSNR_Curve', 'Skewness_DMSNR_Curve']
# 	0.1s = Fit runtime
# 	5 features in original data used to generate 5 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.7 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2399.3s of the 3599.85s of remaining time.
# 	-0.1143	 = Validation score   (-root_mean_squared_error)
# 	0.14s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2398.75s of the 3599.3s of remaining time.
# 	-0.1134	 = Validation score   (-root_mean_squared_error)
# 	0.14s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2398.12s of the 3598.67s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0878	 = Validation score   (-root_mean_squared_error)
# 	29.28s	 = Training   runtime
# 	40.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2356.69s of the 3557.24s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0877	 = Validation score   (-root_mean_squared_error)
# 	1.59s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2352.72s of the 3553.27s of remaining time.
# 	-0.0902	 = Validation score   (-root_mean_squared_error)
# 	21.48s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2329.27s of the 3529.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0867	 = Validation score   (-root_mean_squared_error)
# 	8.69s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2318.37s of the 3518.92s of remaining time.
# 	-0.0891	 = Validation score   (-root_mean_squared_error)
# 	2.55s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2313.41s of the 3513.96s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0874	 = Validation score   (-root_mean_squared_error)
# 	175.08s	 = Training   runtime
# 	1.82s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2135.57s of the 3336.12s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0882	 = Validation score   (-root_mean_squared_error)
# 	1.3s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2131.82s of the 3332.37s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0998	 = Validation score   (-root_mean_squared_error)
# 	330.27s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1798.95s of the 2999.5s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0907	 = Validation score   (-root_mean_squared_error)
# 	2.53s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2994.55s of remaining time.
# 	-0.0863	 = Validation score   (-root_mean_squared_error)
# 	1.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2993.01s of the 2993.0s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0872	 = Validation score   (-root_mean_squared_error)
# 	3.56s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2986.82s of the 2986.8s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0874	 = Validation score   (-root_mean_squared_error)
# 	2.36s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 2981.65s of the 2981.63s of remaining time.
# 	-0.0881	 = Validation score   (-root_mean_squared_error)
# 	71.97s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2907.11s of the 2907.1s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0865	 = Validation score   (-root_mean_squared_error)
# 	6.99s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 2897.41s of the 2897.4s of remaining time.
# 	-0.0874	 = Validation score   (-root_mean_squared_error)
# 	8.74s	 = Training   runtime
# 	2.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2886.03s of the 2886.02s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0867	 = Validation score   (-root_mean_squared_error)
# 	203.7s	 = Training   runtime
# 	2.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2679.4s of the 2679.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0878	 = Validation score   (-root_mean_squared_error)
# 	10.71s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2665.74s of the 2665.72s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.1029	 = Validation score   (-root_mean_squared_error)
# 	226.36s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2436.29s of the 2436.28s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0883	 = Validation score   (-root_mean_squared_error)
# 	4.15s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 2429.42s of remaining time.
# 	-0.0863	 = Validation score   (-root_mean_squared_error)
# 	1.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1172.0s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("autogluon_model_2/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -0.086267      57.266458  1096.354354                0.001946           1.386949            3       True         22
# 1      WeightedEnsemble_L2  -0.086333      47.137641   570.456184                0.002109           1.507957            2       True         12
# 2          CatBoost_BAG_L2  -0.086541      48.618765   580.055256                0.048019           6.992199            2       True         16
# 3   NeuralNetFastAI_BAG_L2  -0.086693      50.784335   776.762270                2.213590         203.699213            2       True         18
# 4          CatBoost_BAG_L1  -0.086722       0.038104     8.688755                0.038104           8.688755            1       True          6
# 5        LightGBMXT_BAG_L2  -0.087209      49.022678   576.621778                0.451932           3.558721            2       True         13
# 6          LightGBM_BAG_L2  -0.087408      48.790828   575.422636                0.220083           2.359579            2       True         14
# 7   NeuralNetFastAI_BAG_L1  -0.087434       1.823796   175.081065                1.823796         175.081065            1       True          8
# 8     ExtraTreesMSE_BAG_L2  -0.087435      51.036722   581.805695                2.465976           8.742637            2       True         17
# 9          LightGBM_BAG_L1  -0.087729       0.210004     1.592373                0.210004           1.592373            1       True          4
# 10          XGBoost_BAG_L2  -0.087770      48.850509   583.770931                0.279764          10.707874            2       True         19
# 11       LightGBMXT_BAG_L1  -0.087804      40.163825    29.284691               40.163825          29.284691            1       True          3
# 12  RandomForestMSE_BAG_L2  -0.088068      50.974695   645.029212                2.403949          71.966155            2       True         15
# 13          XGBoost_BAG_L1  -0.088233       0.215973     1.302374                0.215973           1.302374            1       True          9
# 14    LightGBMLarge_BAG_L2  -0.088312      48.999554   577.208418                0.428808           4.145361            2       True         21
# 15    ExtraTreesMSE_BAG_L1  -0.089141       2.246837     2.551281                2.246837           2.551281            1       True          7
# 16  RandomForestMSE_BAG_L1  -0.090178       1.830218    21.483679                1.830218          21.483679            1       True          5
# 17    LightGBMLarge_BAG_L1  -0.090677       0.406928     2.531563                0.406928           2.531563            1       True         11
# 18   NeuralNetTorch_BAG_L1  -0.099821       0.822747   330.266383                0.822747         330.266383            1       True         10
# 19   NeuralNetTorch_BAG_L2  -0.102950      49.704170   799.421840                1.133424         226.358783            2       True         20
# 20   KNeighborsDist_BAG_L1  -0.113405       0.441369     0.140890                0.441369           0.140890            1       True          2
# 21   KNeighborsUnif_BAG_L1  -0.114308       0.370944     0.140003                0.370944           0.140003            1       True          1
# Number of models trained: 22
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN', 'WeightedEnsembleModel'}
# Bagging used: True  (with 5 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) : 5 | ['SD', 'EK', 'SD_DMSNR_Curve', 'EK_DMSNR_Curve', 'Skewness_DMSNR_Curve']
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -0.11430767582299793,
#   'KNeighborsDist_BAG_L1': -0.11340502651838433,
#   'LightGBMXT_BAG_L1': -0.0878044200898624,
#   'LightGBM_BAG_L1': -0.08772897715363294,
#   'RandomForestMSE_BAG_L1': -0.0901775828899117,
#   'CatBoost_BAG_L1': -0.08672226149555627,
#   'ExtraTreesMSE_BAG_L1': -0.08914080582778895,
#   'NeuralNetFastAI_BAG_L1': -0.087433533551349,
#   'XGBoost_BAG_L1': -0.0882327320132862,
#   'NeuralNetTorch_BAG_L1': -0.0998214222536665,
#   'LightGBMLarge_BAG_L1': -0.09067671959849102,
#   'WeightedEnsemble_L2': -0.08633332539159853,
#   'LightGBMXT_BAG_L2': -0.08720859614690274,
#   'LightGBM_BAG_L2': -0.08740840345224825,
#   'RandomForestMSE_BAG_L2': -0.08806840814201916,
#   'CatBoost_BAG_L2': -0.08654065802892923,
#   'ExtraTreesMSE_BAG_L2': -0.08743496322595519,
#   'NeuralNetFastAI_BAG_L2': -0.08669348807285865,
#   'XGBoost_BAG_L2': -0.08776978588703757,
#   'NeuralNetTorch_BAG_L2': -0.10294971464952403,
#   'LightGBMLarge_BAG_L2': -0.08831238025016262,
#   'WeightedEnsemble_L3': -0.08626739065327327},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'autogluon_model_2/models/KNeighborsUnif_BAG_L1/',
#   'KNeighborsDist_BAG_L1': 'autogluon_model_2/models/KNeighborsDist_BAG_L1/',
#   'LightGBMXT_BAG_L1': 'autogluon_model_2/models/LightGBMXT_BAG_L1/',
#   'LightGBM_BAG_L1': 'autogluon_model_2/models/LightGBM_BAG_L1/',
#   'RandomForestMSE_BAG_L1': 'autogluon_model_2/models/RandomForestMSE_BAG_L1/',
#   'CatBoost_BAG_L1': 'autogluon_model_2/models/CatBoost_BAG_L1/',
#   'ExtraTreesMSE_BAG_L1': 'autogluon_model_2/models/ExtraTreesMSE_BAG_L1/',
#   'NeuralNetFastAI_BAG_L1': 'autogluon_model_2/models/NeuralNetFastAI_BAG_L1/',
#   'XGBoost_BAG_L1': 'autogluon_model_2/models/XGBoost_BAG_L1/',
#   'NeuralNetTorch_BAG_L1': 'autogluon_model_2/models/NeuralNetTorch_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'autogluon_model_2/models/LightGBMLarge_BAG_L1/',
#   'WeightedEnsemble_L2': 'autogluon_model_2/models/WeightedEnsemble_L2/',
#   'LightGBMXT_BAG_L2': 'autogluon_model_2/models/LightGBMXT_BAG_L2/',
#   'LightGBM_BAG_L2': 'autogluon_model_2/models/LightGBM_BAG_L2/',
#   'RandomForestMSE_BAG_L2': 'autogluon_model_2/models/RandomForestMSE_BAG_L2/',
#   'CatBoost_BAG_L2': 'autogluon_model_2/models/CatBoost_BAG_L2/',
#   'ExtraTreesMSE_BAG_L2': 'autogluon_model_2/models/ExtraTreesMSE_BAG_L2/',
#   'NeuralNetFastAI_BAG_L2': 'autogluon_model_2/models/NeuralNetFastAI_BAG_L2/',
#   'XGBoost_BAG_L2': 'autogluon_model_2/models/XGBoost_BAG_L2/',
#   'NeuralNetTorch_BAG_L2': 'autogluon_model_2/models/NeuralNetTorch_BAG_L2/',
#   'LightGBMLarge_BAG_L2': 'autogluon_model_2/models/LightGBMLarge_BAG_L2/',
#   'WeightedEnsemble_L3': 'autogluon_model_2/models/WeightedEnsemble_L3/'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.14000344276428223,
#   'KNeighborsDist_BAG_L1': 0.14089012145996094,
#   'LightGBMXT_BAG_L1': 29.284691333770752,
#   'LightGBM_BAG_L1': 1.5923728942871094,
#   'RandomForestMSE_BAG_L1': 21.483678579330444,
#   'CatBoost_BAG_L1': 8.688754796981812,
#   'ExtraTreesMSE_BAG_L1': 2.551280975341797,
#   'NeuralNetFastAI_BAG_L1': 175.08106541633606,
#   'XGBoost_BAG_L1': 1.3023738861083984,
#   'NeuralNetTorch_BAG_L1': 330.2663826942444,
#   'LightGBMLarge_BAG_L1': 2.5315630435943604,
#   'WeightedEnsemble_L2': 1.5079572200775146,
#   'LightGBMXT_BAG_L2': 3.5587210655212402,
#   'LightGBM_BAG_L2': 2.359579086303711,
#   'RandomForestMSE_BAG_L2': 71.96615505218506,
#   'CatBoost_BAG_L2': 6.992198705673218,
#   'ExtraTreesMSE_BAG_L2': 8.742637395858765,
#   'NeuralNetFastAI_BAG_L2': 203.69921278953552,
#   'XGBoost_BAG_L2': 10.707874059677124,
#   'NeuralNetTorch_BAG_L2': 226.3587827682495,
#   'LightGBMLarge_BAG_L2': 4.145360946655273,
#   'WeightedEnsemble_L3': 1.386949062347412},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.3709440231323242,
#   'KNeighborsDist_BAG_L1': 0.44136881828308105,
#   'LightGBMXT_BAG_L1': 40.163825035095215,
#   'LightGBM_BAG_L1': 0.21000432968139648,
#   'RandomForestMSE_BAG_L1': 1.8302183151245117,
#   'CatBoost_BAG_L1': 0.03810405731201172,
#   'ExtraTreesMSE_BAG_L1': 2.2468371391296387,
#   'NeuralNetFastAI_BAG_L1': 1.823796272277832,
#   'XGBoost_BAG_L1': 0.2159726619720459,
#   'NeuralNetTorch_BAG_L1': 0.822746753692627,
#   'LightGBMLarge_BAG_L1': 0.40692830085754395,
#   'WeightedEnsemble_L2': 0.0021088123321533203,
#   'LightGBMXT_BAG_L2': 0.451932430267334,
#   'LightGBM_BAG_L2': 0.22008252143859863,
#   'RandomForestMSE_BAG_L2': 2.403949499130249,
#   'CatBoost_BAG_L2': 0.0480189323425293,
#   'ExtraTreesMSE_BAG_L2': 2.4659762382507324,
#   'NeuralNetFastAI_BAG_L2': 2.213589668273926,
#   'XGBoost_BAG_L2': 0.27976369857788086,
#   'NeuralNetTorch_BAG_L2': 1.1334238052368164,
#   'LightGBMLarge_BAG_L2': 0.42880797386169434,
#   'WeightedEnsemble_L3': 0.0019464492797851562},
#  'num_bag_folds': 5,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val  pred_time_val     fit_time  \
#  0      WeightedEnsemble_L3  -0.086267      57.266458  1096.354354
#  1      WeightedEnsemble_L2  -0.086333      47.137641   570.456184
#  2          CatBoost_BAG_L2  -0.086541      48.618765   580.055256
#  3   NeuralNetFastAI_BAG_L2  -0.086693      50.784335   776.762270
#  4          CatBoost_BAG_L1  -0.086722       0.038104     8.688755
#  5        LightGBMXT_BAG_L2  -0.087209      49.022678   576.621778
#  6          LightGBM_BAG_L2  -0.087408      48.790828   575.422636
#  7   NeuralNetFastAI_BAG_L1  -0.087434       1.823796   175.081065
#  8     ExtraTreesMSE_BAG_L2  -0.087435      51.036722   581.805695
#  9          LightGBM_BAG_L1  -0.087729       0.210004     1.592373
#  10          XGBoost_BAG_L2  -0.087770      48.850509   583.770931
#  11       LightGBMXT_BAG_L1  -0.087804      40.163825    29.284691
#  12  RandomForestMSE_BAG_L2  -0.088068      50.974695   645.029212
#  13          XGBoost_BAG_L1  -0.088233       0.215973     1.302374
#  14    LightGBMLarge_BAG_L2  -0.088312      48.999554   577.208418
#  15    ExtraTreesMSE_BAG_L1  -0.089141       2.246837     2.551281
#  16  RandomForestMSE_BAG_L1  -0.090178       1.830218    21.483679
#  17    LightGBMLarge_BAG_L1  -0.090677       0.406928     2.531563
#  18   NeuralNetTorch_BAG_L1  -0.099821       0.822747   330.266383
#  19   NeuralNetTorch_BAG_L2  -0.102950      49.704170   799.421840
#  20   KNeighborsDist_BAG_L1  -0.113405       0.441369     0.140890
#  21   KNeighborsUnif_BAG_L1  -0.114308       0.370944     0.140003
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.001946           1.386949            3       True
#  1                 0.002109           1.507957            2       True
#  2                 0.048019           6.992199            2       True
#  3                 2.213590         203.699213            2       True
#  4                 0.038104           8.688755            1       True
#  5                 0.451932           3.558721            2       True
#  6                 0.220083           2.359579            2       True
#  7                 1.823796         175.081065            1       True
#  8                 2.465976           8.742637            2       True
#  9                 0.210004           1.592373            1       True
#  10                0.279764          10.707874            2       True
#  11               40.163825          29.284691            1       True
#  12                2.403949          71.966155            2       True
#  13                0.215973           1.302374            1       True
#  14                0.428808           4.145361            2       True
#  15                2.246837           2.551281            1       True
#  16                1.830218          21.483679            1       True
#  17                0.406928           2.531563            1       True
#  18                0.822747         330.266383            1       True
#  19                1.133424         226.358783            2       True
#  20                0.441369           0.140890            1       True
#  21                0.370944           0.140003            1       True
#
#      fit_order
#  0          22
#  1          12
#  2          16
#  3          18
#  4           6
#  5          13
#  6          14
#  7           8
#  8          17
#  9           4
#  10         19
#  11          3
#  12         15
#  13          9
#  14         21
#  15          7
#  16          5
#  17         11
#  18         10
#  19         20
#  20          2
#  21          1  }

# %%
predictor = TabularPredictor.load(MODEL_SAVE_PATH) 
pred_test = predictor.predict(test_data_transform)

# pd.DataFrame(pred_test).to_csv("submission.csv", header=True)
pd.concat([test_data_id, pred_test], axis=1).to_csv("submission.csv", header=True, index=False)

# %%
predictor.persist_models()
# Out:
# Persisting 18 models in memory. Models will require 0.71% of memory.
# ['LightGBM_BAG_L1',
#  'LightGBMXT_BAG_L1',
#  'ExtraTreesMSE_BAG_L1',
#  'NeuralNetTorch_BAG_L2',
#  'CatBoost_BAG_L1',
#  'NeuralNetTorch_BAG_L1',
#  'LightGBMLarge_BAG_L1',
#  'XGBoost_BAG_L1',
#  'RandomForestMSE_BAG_L2',
#  'LightGBMLarge_BAG_L2',
#  'WeightedEnsemble_L3',
#  'NeuralNetFastAI_BAG_L1',
#  'CatBoost_BAG_L2',
#  'KNeighborsUnif_BAG_L1',
#  'KNeighborsDist_BAG_L1',
#  'NeuralNetFastAI_BAG_L2',
#  'RandomForestMSE_BAG_L1',
#  'ExtraTreesMSE_BAG_L2']
