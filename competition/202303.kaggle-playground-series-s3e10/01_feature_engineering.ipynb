# %%
import numpy as np
import pandas as pd 
import os 
import random
import warnings
warnings.filterwarnings(action='ignore')

from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.eda.auto as auto
from sklearn.model_selection import GroupKFold

# %%
TRAIN_PATH = "playground-series-s3e10/train.csv"
TEST_PATH = "playground-series-s3e10/test.csv"
SAMPLE_SUBISSION_PATH = "playground-series-s3e10/sample_submission.csv"
SUBMISSION_PATH = "submission.csv"
TARGET = "Class"
NEGATIVE_FEATURES = "negative_features"

SEED = 2022
def seed_everything(seed=SEED):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything()

MODEL_SAVE_PATH = "output/playground-series-s3e10_feature_engineering/"
MODEL_VERBOSE = 2
MODEL_PRESETS = "best_quality"
TIME_LIMIT = 120

NUM_BAG_FOLDS = 5
NUM_BAG_SETS = 1
NUM_STACK_LEVELS = 1

# %%
train_data = pd.read_csv(TRAIN_PATH)

# %%
from autogluon.features.generators import AutoMLPipelineFeatureGenerator

auto_ml_pipeline_feature_generator = AutoMLPipelineFeatureGenerator()

train_data_features = train_data.drop([TARGET, "id"], axis=1)
train_data_features_transform = auto_ml_pipeline_feature_generator.fit_transform(X=train_data_features)

train_data_features_transform.describe()
# Out:
#        Mean_Integrated             SD             EK       Skewness  \
# count    117564.000000  117564.000000  117564.000000  117564.000000
# mean        111.248300      46.713535       0.503498       1.886385
# std          24.906474       6.102941       1.127093       6.515466
# min           6.054688      24.783273      -1.730782      -1.791886
# 25%         104.546875      43.443390       0.049761      -0.188956
# 50%         116.664062      47.478932       0.186498       0.091720
# 75%         126.296875      50.862718       0.395620       0.691613
# max         189.367188      93.602933       7.879628      65.385974
#
#        Mean_DMSNR_Curve  SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve
# count     117564.000000   117564.000000   117564.000000         117564.000000
# mean          11.962921       26.190678        8.037488             93.881076
# std           26.719946       20.041937        3.840980             79.962110
# min            0.213211        7.370432       -2.597872             -1.976976
# 25%            2.090301       14.955405        6.742911             49.409136
# 50%            2.808528       18.164924        8.442883             83.421375
# 75%            4.122910       24.732218       10.003237            122.093290
# max          217.371238      109.890785       34.539844           1191.000837

# %%
train_data_features_transform[TARGET] = train_data[TARGET]

# %%
# https://stackoverflow.com/questions/56191448/sample-pandas-dataframe-based-on-values-in-column
# sample by group
train_data_features_transform_test =  train_data_features_transform.groupby(TARGET).sample(frac=0.25, random_state=1)
train_data_features_transform_test.head()
# Out:
#         Mean_Integrated         SD        EK  Skewness  Mean_DMSNR_Curve  \
# 83648        122.093750  53.945660 -0.027460 -0.506680          4.076923
# 113745       116.867188  48.754745  0.254735  0.067584          3.015050
# 103750       126.359375  46.442499  0.075528  0.176053          2.556020
# 34497        151.000000  46.673078 -0.338401  0.064067          3.020903
# 50996        130.578125  50.161891  0.003526 -0.164029          2.141304
#
#         SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve  Class
# 83648        22.929187        7.049416             56.839443      0
# 113745       17.572804        8.118838             80.715410      0
# 103750       17.559953        8.734353             89.873374      0
# 34497        19.438980        8.073839             72.967109      0
# 50996        19.382942        9.599411             96.829541      0

# %%
sample_idxs = train_data_features_transform_test.index.tolist()
train_data_features_transform_train = train_data_features_transform.drop(sample_idxs, axis="index")
train_data_features_transform_train.head()
# Out:
#    Mean_Integrated         SD        EK  Skewness  Mean_DMSNR_Curve  \
# 0       133.171875  59.716081  0.043133 -0.703383         54.917224
# 2       112.640625  39.818393  0.379639  0.922306          2.730769
# 3       120.679688  45.918448 -0.098490  0.011775          2.696488
# 5       131.632812  52.563210 -0.075253 -0.495825          2.194816
# 7       120.203125  49.927902 -0.089990 -0.321367          3.280100
#
#    SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve  Class
# 0       70.084438        0.749798             -0.649512      0
# 2       15.689690        8.193471             85.649785      0
# 3       20.954662        8.183874             70.332899      0
# 5       15.537425        9.033439             97.032406      0
# 7       18.376840        8.190561             77.917237      0

# %%
print(train_data_features_transform_train.shape)
print(train_data_features_transform_test.shape)
# Out:
# (88173, 9)
# (29391, 9)

# %%
predictor = TabularPredictor(
    label=TARGET, 
    path=MODEL_SAVE_PATH, 
    verbosity=MODEL_VERBOSE).fit(
    train_data_features_transform_train, 
    time_limit=TIME_LIMIT, 
    presets=MODEL_PRESETS, 
    num_bag_folds=NUM_BAG_FOLDS, 
    num_bag_sets=NUM_BAG_SETS, 
    num_stack_levels=NUM_STACK_LEVELS
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="output/playground-series-s3e10_feature_engineering/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 120s
# AutoGluon will save models to "output/playground-series-s3e10_feature_engineering/"
# AutoGluon Version:  0.6.3b20230205
# Python Version:     3.9.0
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #161-Ubuntu SMP Fri Feb 3 14:49:04 UTC 2023
# Train Data Rows:    88173
# Train Data Columns: 8
# Label Column: Class
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    42385.76 MB
# 	Train Data (Original)  Memory Usage: 5.64 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['Mean_Integrated', 'SD', 'EK', 'Skewness', 'Mean_DMSNR_Curve', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 8 | ['Mean_Integrated', 'SD', 'EK', 'Skewness', 'Mean_DMSNR_Curve', ...]
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 5.64 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 79.9s of the 119.88s of remaining time.
# 	0.988	 = Validation score   (accuracy)
# 	0.19s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 78.78s of the 118.76s of remaining time.
# 	0.9879	 = Validation score   (accuracy)
# 	0.19s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 77.66s of the 117.63s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9909	 = Validation score   (accuracy)
# 	3.26s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 68.83s of the 108.81s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9913	 = Validation score   (accuracy)
# 	1.63s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 64.86s of the 104.84s of remaining time.
# 	0.9911	 = Validation score   (accuracy)
# 	6.96s	 = Training   runtime
# 	2.18s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 54.97s of the 94.94s of remaining time.
# 	0.9912	 = Validation score   (accuracy)
# 	6.87s	 = Training   runtime
# 	2.08s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 45.29s of the 85.27s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9912	 = Validation score   (accuracy)
# 	7.71s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 35.08s of the 75.06s of remaining time.
# 	0.9911	 = Validation score   (accuracy)
# 	2.49s	 = Training   runtime
# 	2.44s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 29.07s of the 69.05s of remaining time.
# 	0.991	 = Validation score   (accuracy)
# 	2.37s	 = Training   runtime
# 	2.5s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 23.58s of the 63.56s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9908	 = Validation score   (accuracy)
# 	14.59s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 6.17s of the 46.14s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9912	 = Validation score   (accuracy)
# 	1.42s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2.11s of the 42.08s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 119.88s of the 38.43s of remaining time.
# 2023-03-12 15:12:50,072	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-03-12 15:12:50,093	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-03-12 15:12:50,095	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-03-12 15:12:50,096	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.9914	 = Validation score   (accuracy)
# 	26.33s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 11.88s of the 11.87s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9913	 = Validation score   (accuracy)
# 	1.78s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 7.66s of the 7.64s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.9914	 = Validation score   (accuracy)
# 	1.77s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 3.26s of the 3.25s of remaining time.
# 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 14.37s compared to 10s of available time.
# 	Time limit exceeded... Skipping RandomForestGini_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 119.88s of the -8.32s of remaining time.
# 	0.9914	 = Validation score   (accuracy)
# 	5.26s	 = Training   runtime
# 	0.19s	 = Validation runtime
# AutoGluon training complete, total runtime = 133.87s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("output/playground-series-s3e10_feature_engineering/")

# %%
predictor = TabularPredictor.load(MODEL_SAVE_PATH) 
pred_test = predictor.predict(train_data_features_transform_test)

predictor.leaderboard(train_data_features_transform_test, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0           CatBoost_BAG_L1    0.990575   0.991188        0.077526
# 1     ExtraTreesEntr_BAG_L1    0.990575   0.990995        0.222032
# 2            XGBoost_BAG_L1    0.990473   0.991222        0.092498
# 3           LightGBM_BAG_L1    0.990473   0.991301        0.102826
# 4     ExtraTreesGini_BAG_L1    0.990405   0.991052        0.258766
# 5       WeightedEnsemble_L2    0.990405   0.991403        0.795659
# 6         LightGBMXT_BAG_L2    0.990405   0.991324        4.362384
# 7         LightGBMXT_BAG_L1    0.990371   0.990882        0.422875
# 8   RandomForestGini_BAG_L1    0.990337   0.991063        0.208123
# 9    NeuralNetFastAI_BAG_L1    0.990337   0.990779        2.292827
# 10          LightGBM_BAG_L2    0.990201   0.991392        4.352613
# 11      WeightedEnsemble_L3    0.990201   0.991392        4.354642
# 12  RandomForestEntr_BAG_L1    0.990133   0.991154        0.203281
# 13    KNeighborsUnif_BAG_L1    0.987853   0.987967        0.204460
# 14    KNeighborsDist_BAG_L1    0.987785   0.987933        0.220735
#
#     pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.036767   7.711259                 0.077526                0.036767
# 1        2.497108   2.372678                 0.222032                2.497108
# 2        0.106954   1.415082                 0.092498                0.106954
# 3        0.120411   1.628629                 0.102826                0.120411
# 4        2.440366   2.493839                 0.258766                2.440366
# 5        7.427211  39.789535                 0.003911                0.191828
# 6       12.836717  49.457833                 0.056434                0.094537
# 7        0.896195   3.262503                 0.422875                0.896195
# 8        2.177496   6.962677                 0.208123                2.177496
# 9        1.378218  14.587529                 2.292827                1.378218
# 10      12.812605  49.446784                 0.046664                0.070426
# 11      13.006234  54.707527                 0.002029                0.193629
# 12       2.080686   6.869367                 0.203281                2.080686
# 13       0.504797   0.186360                 0.204460                0.504797
# 14       0.503180   0.186399                 0.220735                0.503180
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            7.711259            1       True          7
# 1            2.372678            1       True          9
# 2            1.415082            1       True         11
# 3            1.628629            1       True          4
# 4            2.493839            1       True          8
# 5           26.331710            2       True         12
# 6            1.781510            2       True         13
# 7            3.262503            1       True          3
# 8            6.962677            1       True          5
# 9           14.587529            1       True         10
# 10           1.770461            2       True         14
# 11           5.260743            3       True         15
# 12           6.869367            1       True          6
# 13           0.186360            1       True          1
# 14           0.186399            1       True          2

# %%
feature_importances = predictor.feature_importance(train_data_features_transform_test)
# Out:
# Computing feature importance via permutation shuffling for 8 features using 5000 rows with 5 shuffle sets...
# 	20.3s	= Expected runtime (4.06s per shuffle set)
# 	7.35s	= Actual runtime (Completed 5 of 5 shuffle sets)

# %%
print("特徴量の重要度:")
display(feature_importances)
# Out:
# 特徴量の重要度:
#                       importance    stddev       p_value  n  p99_high  \
# EK                       0.15396  0.005620  2.127270e-07  5  0.165532
# SD                       0.00196  0.001203  1.096156e-02  5  0.004438
# Skewness_DMSNR_Curve     0.00044  0.000498  5.969670e-02  5  0.001465
# EK_DMSNR_Curve           0.00008  0.000415  3.442285e-01  5  0.000934
# SD_DMSNR_Curve           0.00004  0.000639  4.477029e-01  5  0.001355
# Skewness                -0.00004  0.000329  6.005171e-01  5  0.000637
# Mean_DMSNR_Curve        -0.00020  0.000583  7.570669e-01  5  0.001001
# Mean_Integrated         -0.00024  0.000385  8.822518e-01  5  0.000552
#
#                        p99_low
# EK                    0.142388
# SD                   -0.000518
# Skewness_DMSNR_Curve -0.000585
# EK_DMSNR_Curve       -0.000774
# SD_DMSNR_Curve       -0.001275
# Skewness             -0.000717
# Mean_DMSNR_Curve     -0.001401
# Mean_Integrated      -0.001032

# %%
feature_importances.to_csv("feature_importances.csv")
