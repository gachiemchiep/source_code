# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import gc
import pickle
import random
from pathlib import Path

import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, GroupKFold
from sklearn.metrics import mean_squared_error

# %%
class CFG:
    VER = 1
    AUTHOR = 'takaito'
    METHOD = 'lightgbm'
    COMPETITION = 'ocean180'
    DATA_PATH = Path('dataset') # データへのpathを設定
    target_col = 'cover'
    seed = 42
    num_fold = 3
    boosting_type = 'gbdt'
    lgb_params = {
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.1,
        'boosting': boosting_type,
        'seed': seed,
    }

# %%
def preprocessing(input_df: pd.DataFrame)->pd.DataFrame:
    output_df = input_df.copy()
    # 特徴量を追加していく
    return output_df
def get_train_data()->pd.DataFrame:
    df = pd.read_csv(CFG.DATA_PATH / 'train_data.csv').drop(['Unnamed: 0', 'YMD', 'Landsat_StartTime', 'PRODUCT_ID'], axis=1)
    return preprocessing(df)
def get_test_data():
    df = pd.read_csv(CFG.DATA_PATH / 'test_data.csv').drop(['Unnamed: 0', 'YMD', 'Landsat_StartTime', 'PRODUCT_ID'], axis=1)
    return preprocessing(df)

# %%
def get_groupkfold(train, target_col, group_col, n_splits):
    kf = GroupKFold(n_splits=n_splits)
    generator = kf.split(train, train[target_col], train[group_col])
    fold_series = []
    for fold, (idx_train, idx_valid) in enumerate(generator):
        fold_series.append(pd.Series(fold, index=idx_valid))
    fold_series = pd.concat(fold_series).sort_index()
    return fold_series
def lgb_training(train, features):
    CFG.folds = get_groupkfold(train, CFG.target_col, 'mesh20', CFG.num_fold)
    CFG.folds.to_csv('folds.csv', index=False)
    oof_pred = np.zeros(len(train), dtype=np.float64)
    df_importance = pd.DataFrame({'feature': features})
    df_importance['importance'] = 0
    for fold in range(CFG.num_fold):
        idx_train = CFG.folds!=fold
        idx_valid = CFG.folds==fold
        x_train = train[idx_train][features]
        y_train = train[idx_train][CFG.target_col]
        x_valid = train[idx_valid][features]
        y_valid = train[idx_valid][CFG.target_col]
        lgb_train = lgb.Dataset(x_train, y_train)
        lgb_valid = lgb.Dataset(x_valid, y_valid)
        model = lgb.train(
            params = CFG.lgb_params,
            train_set = lgb_train,
            num_boost_round = 1000,
            valid_sets = [lgb_train, lgb_valid],
            early_stopping_rounds = 100,
            verbose_eval = 50,
        )
        model_path = f'{CFG.METHOD}_fold{fold}_seed{CFG.seed}_ver{CFG.VER}.pkl'
        pickle.dump(model, open(model_path, 'wb'))
        oof_pred[idx_valid] = model.predict(x_valid)

        f_importance = np.array(model.feature_importance())
        temp_importance = pd.DataFrame({'feature': features, 'importance': f_importance})
        df_importance['importance'] += temp_importance['importance']

    df_importance['importance'] = df_importance['importance'] / np.sum(df_importance['importance'])
    df_importance = df_importance.sort_values('importance', ascending=False)
    df_importance.to_csv(f'{CFG.METHOD}_feature_importance_seed{CFG.seed}_ver{CFG.VER}.csv', header=True, index=False)
    display(df_importance.head(50))
    score = np.sqrt(mean_squared_error(train[CFG.target_col], oof_pred))
    np.save(f'oof_pred_{CFG.METHOD}_seed{CFG.seed}_ver{CFG.VER}', oof_pred)
    print(f'CV Score: {score}')

# %%
def lgb_Predicting(test, features):
    test_preds = np.zeros((len(test), CFG.num_fold))
    x_test = test[features]
    for fold in range(CFG.num_fold):
        model_path = f'{CFG.METHOD}_fold{fold}_seed{CFG.seed}_ver{CFG.VER}.pkl'
        model = pickle.load(open(model_path, 'rb'))
        test_preds[:, fold] = model.predict(x_test)
    np.save(f'oof_pred_{CFG.METHOD}_seed{CFG.seed}_ver{CFG.VER}', test_preds)
    pd.DataFrame(np.mean(test_preds, axis=1)).to_csv(f'submit_{CFG.METHOD}_seed{CFG.seed}_ver{CFG.VER}.csv', header=False)

# %%
train = get_train_data()
test = get_test_data()
features = list(train.drop([CFG.target_col, 'mesh20'], axis=1))
lgb_training(train, features)
lgb_Predicting(test, features)
# Out:
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.361738 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 879722
# [LightGBM] [Info] Number of data points in the train set: 9425, number of used features: 3459
# [LightGBM] [Info] Start training from score 0.211930
# Training until validation scores don't improve for 100 rounds
# [50]	training's rmse: 0.0754667	valid_1's rmse: 0.198665
# [100]	training's rmse: 0.0567183	valid_1's rmse: 0.200235
# Early stopping, best iteration is:
# [14]	training's rmse: 0.128005	valid_1's rmse: 0.19586
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.414042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 879849
# [LightGBM] [Info] Number of data points in the train set: 9429, number of used features: 3459
# [LightGBM] [Info] Start training from score 0.162047
# Training until validation scores don't improve for 100 rounds
# [50]	training's rmse: 0.0770266	valid_1's rmse: 0.20184
# [100]	training's rmse: 0.0561219	valid_1's rmse: 0.201596
# [150]	training's rmse: 0.0448069	valid_1's rmse: 0.201289
# Early stopping, best iteration is:
# [75]	training's rmse: 0.0644221	valid_1's rmse: 0.200648
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/gachiemchiep/anaconda3/envs/ocr-py3/lib/python3.9/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.376772 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 879851
# [LightGBM] [Info] Number of data points in the train set: 9426, number of used features: 3459
# [LightGBM] [Info] Start training from score 0.175582
# Training until validation scores don't improve for 100 rounds
# [50]	training's rmse: 0.0767807	valid_1's rmse: 0.195513
# [100]	training's rmse: 0.0572677	valid_1's rmse: 0.198365
# Early stopping, best iteration is:
# [40]	training's rmse: 0.0839509	valid_1's rmse: 0.194903
#                   feature  importance
# 5          depth_original    0.012403
# 15          hist_warm_sst    0.011111
# 19               warm_sst    0.010594
# 2                    area    0.007494
# 270              MIN_GARI    0.007235
# 4                   month    0.005943
# 12                  depth    0.005943
# 13                  fetch    0.005943
# 3005          MIN_IF_2017    0.005685
# 3                    year    0.005168
# 82          Date_Acquired    0.005168
# 21                sst_ymd    0.005168
# 17             river_dist    0.004910
# 3309        MAX_Blue_2020    0.003876
# 22               sst_diff    0.003359
# 2865       MAX_TIRS1_2017    0.003101
# 2809        MIN_Blue_2016    0.003101
# 9            coast_length    0.003101
# 2265       MAX_TIRS1_2013    0.003101
# 264          MIN_D678_500    0.003101
# 2965       MIN_TIRS1_2017    0.002842
# 78                  SIPI2    0.002842
# 2355          MED_IF_2013    0.002584
# 0                     lat    0.002584
# 2680      MIN_DVIMSS_2015    0.002584
# 3242           MED_H_2019    0.002584
# 2541         MIN_GLI_2014    0.002326
# 2277        MAX_CTVI_2013    0.002326
# 73                    PPR    0.002326
# 1608   MED_VARIgreen_2008    0.002326
# 277                MIN_IO    0.002326
# 195              MED_GARI    0.002326
# 3281        MIN_DSWI_2019    0.002326
# 2518  MIN_Alteration_2014    0.002067
# 2441         MAX_GLI_2014    0.002067
# 2365       MIN_TIRS1_2013    0.002067
# 1558   MAX_VARIgreen_2008    0.002067
# 3115       MIN_TIRS1_2018    0.002067
# 237              MIN_ARVI    0.002067
# 2758   MAX_VARIgreen_2016    0.002067
# 3458   MIN_VARIgreen_2020    0.002067
# 24                  Green    0.002067
# 26                    NIR    0.002067
# 1096         MAX_MVI_2005    0.001809
# 1192           MIN_H_2005    0.001809
# 3215       MED_TIRS1_2019    0.001809
# 3015       MAX_TIRS1_2018    0.001809
# 639       MAX_Gossan_2002    0.001809
# 3338        MAX_GVMI_2020    0.001809
# 63                      H    0.001809
# CV Score: 0.19715192675748644

# %%
len(features)
# Out:
# 3459

# %%
train.shape
# Out:
# (14140, 3461)

# %%
test.shape
# Out:
# (4039, 3460)

# %%
features
# Out:
# ['lat',
#  'lon',
#  'area',
#  'year',
#  'month',
#  'depth_original',
#  'cliff_length',
#  'aicial_length',
#  'beach_length',
#  'coast_length',
#  'coastal_dist',
#  'cold_sst',
#  'depth',
#  'fetch',
#  'hist_cold_sst',
#  'hist_warm_sst',
#  'river_area',
#  'river_dist',
#  'Salinity_annual',
#  'warm_sst',
#  'sst_annual',
#  'sst_ymd',
#  'sst_diff',
#  'Blue',
#  'Green',
#  'Red',
#  'NIR',
#  'SWIR1',
#  'TIRS1',
#  'TIRS2',
#  'SWIR2',
#  'MSAVI',
#  'EVI',
#  'NBR',
#  'NBR2',
#  'NDMI',
#  'NDVI',
#  'NDWI',
#  'SAVI',
#  'TSAVI',
#  'Alteration',
#  'AVI',
#  'BWDRVI',
#  'Chlgreen',
#  'Cigreen',
#  'Cirededge',
#  'Chlred_edge',
#  'CVI',
#  'CI',
#  'CTVI',
#  'CRI550',
#  'D678_500',
#  'DVIMSS',
#  'DSWI',
#  'DSWI_5',
#  'Fe3',
#  'Ferric_Oxides',
#  'Ferrous_Silicates',
#  'GEMI',
#  'GVMI',
#  'Gossan',
#  'GARI',
#  'GLI',
#  'H',
#  'IR550',
#  'mCRIG',
#  'mCRIRE',
#  'MVI',
#  'MCARI1',
#  'MCARI2',
#  'NLI',
#  'NormG',
#  'NormR',
#  'PPR',
#  'PSNDc2',
#  'RDVI',
#  'IF',
#  'SLAVI',
#  'SIPI2',
#  'VARIgreen',
#  'sunAzimuth',
#  'sunElevation',
#  'Date_Acquired',
#  'Landsat_num',
#  'MAX_AFRI1600',
#  'MAX_AOT',
#  'MAX_ARI',
#  'MAX_ARVI',
#  'MAX_AVI',
#  'MAX_B02',
#  'MAX_B03',
#  'MAX_B04',
#  'MAX_B05',
#  'MAX_B06',
#  'MAX_B07',
#  'MAX_B11',
#  'MAX_B12',
#  'MAX_B8A',
#  'MAX_BB1',
#  'MAX_Bcc',
#  'MAX_BGI',
#  'MAX_BNDVI',
#  'MAX_BOA',
#  'MAX_BRI',
#  'MAX_BWDRVI',
#  'MAX_CARI',
#  'MAX_Chlgreen',
#  'MAX_Chlred_edge',
#  'MAX_CI',
#  'MAX_CIgreen',
#  'MAX_CIrededge',
#  'MAX_CLD',
#  'MAX_CRred',
#  'MAX_CSI',
#  'MAX_CVI',
#  'MAX_D678_500',
#  'MAX_Datt1',
#  'MAX_Datt4',
#  'MAX_DVI',
#  'MAX_EVI',
#  'MAX_ExG',
#  'MAX_GARI',
#  'MAX_GDVI',
#  'MAX_GI',
#  'MAX_GLI',
#  'MAX_GRNDVI',
#  'MAX_GVMI',
#  'MAX_IF',
#  'MAX_IO',
#  'MAX_IPVI',
#  'MAX_MCARI_MTVI2',
#  'MAX_MCARI_OSAVI',
#  'MAX_MCARI2',
#  'MAX_MGVI',
#  'MAX_MIRBI',
#  'MAX_mNDVI',
#  'MAX_MNSI',
#  'MAX_MSBI',
#  'MAX_MSI',
#  'MAX_mSR',
#  'MAX_MSR670',
#  'MAX_MVI',
#  'MAX_MYVI',
#  'MAX_NBR2',
#  'MAX_NDBI',
#  'MAX_NDFI2',
#  'MAX_NDII',
#  'MAX_NDRE',
#  'MAX_NDSI',
#  'MAX_NDVI2',
#  'MAX_NDVIre',
#  'MAX_NDWI2',
#  'MAX_PSSRc2',
#  'MAX_RDI',
#  'MAX_Rededge1',
#  'MAX_RGR',
#  'MAX_SB550',
#  'MAX_SR672_708',
#  'MAX_TCI',
#  'MAX_WVP',
#  'MED_AFRI1600',
#  'MED_AOT',
#  'MED_ARI',
#  'MED_ARVI',
#  'MED_AVI',
#  'MED_B02',
#  'MED_B03',
#  'MED_B04',
#  'MED_B05',
#  'MED_B06',
#  'MED_B07',
#  'MED_B11',
#  'MED_B12',
#  'MED_B8A',
#  'MED_BB1',
#  'MED_Bcc',
#  'MED_BGI',
#  'MED_BNDVI',
#  'MED_BOA',
#  'MED_BRI',
#  'MED_BWDRVI',
#  'MED_CARI',
#  'MED_Chlred_edge',
#  'MED_CIgreen',
#  'MED_CIrededge',
#  'MED_CLD',
#  'MED_CRred',
#  'MED_CSI',
#  'MED_CVI',
#  'MED_D678_500',
#  'MED_Datt1',
#  'MED_Datt4',
#  'MED_DVI',
#  'MED_EVI',
#  'MED_ExG',
#  'MED_GARI',
#  'MED_GDVI',
#  'MED_GI',
#  'MED_GLI',
#  'MED_GRNDVI',
#  'MED_GVMI',
#  'MED_IF',
#  'MED_IO',
#  'MED_IPVI',
#  'MED_MCARI_MTVI2',
#  'MED_MCARI_OSAVI',
#  'MED_MCARI2',
#  'MED_MGVI',
#  'MED_MIRBI',
#  'MED_mNDVI',
#  'MED_MNSI',
#  'MED_MSBI',
#  'MED_MSI',
#  'MED_mSR',
#  'MED_MSR670',
#  'MED_MVI',
#  'MED_MYVI',
#  'MED_NBR2',
#  'MED_NDBI',
#  'MED_NDFI2',
#  'MED_NDII',
#  'MED_NDRE',
#  'MED_NDSI',
#  'MED_NDVI2',
#  'MED_NDVIre',
#  'MED_NDWI2',
#  'MED_PSSRc2',
#  'MED_RDI',
#  'MED_Rededge1',
#  'MED_RGR',
#  'MED_SB550',
#  'MED_SR672_708',
#  'MED_TCI',
#  'MED_WVP',
#  'MIN_AFRI1600',
#  'MIN_AOT',
#  'MIN_ARI',
#  'MIN_ARVI',
#  'MIN_AVI',
#  'MIN_B02',
#  'MIN_B03',
#  'MIN_B04',
#  'MIN_B05',
#  'MIN_B06',
#  'MIN_B07',
#  'MIN_B11',
#  'MIN_B12',
#  'MIN_B8A',
#  'MIN_BB1',
#  'MIN_Bcc',
#  'MIN_BGI',
#  'MIN_BNDVI',
#  'MIN_BOA',
#  'MIN_BRI',
#  'MIN_BWDRVI',
#  'MIN_CARI',
#  'MIN_Chlgreen',
#  'MIN_Chlred_edge',
#  'MIN_CIgreen',
#  'MIN_CIrededge',
#  'MIN_CLD',
#  'MIN_CRred',
#  'MIN_CSI',
#  'MIN_CVI',
#  'MIN_D678_500',
#  'MIN_Datt1',
#  'MIN_Datt4',
#  'MIN_DVI',
#  'MIN_EVI',
#  'MIN_ExG',
#  'MIN_GARI',
#  'MIN_GDVI',
#  'MIN_GI',
#  'MIN_GLI',
#  'MIN_GRNDVI',
#  'MIN_GVMI',
#  'MIN_IF',
#  'MIN_IO',
#  'MIN_IPVI',
#  'MIN_MCARI_MTVI2',
#  'MIN_MCARI_OSAVI',
#  'MIN_MCARI2',
#  'MIN_MGVI',
#  'MIN_MIRBI',
#  'MIN_mNDVI',
#  'MIN_MNSI',
#  'MIN_MSBI',
#  'MIN_MSI',
#  'MIN_mSR',
#  'MIN_MSR670',
#  'MIN_MVI',
#  'MIN_MYVI',
#  'MIN_NBR2',
#  'MIN_NDBI',
#  'MIN_NDFI2',
#  'MIN_NDII',
#  'MIN_NDRE',
#  'MIN_NDSI',
#  'MIN_NDVI2',
#  'MIN_NDVIre',
#  'MIN_NDWI2',
#  'MIN_PSSRc2',
#  'MIN_RDI',
#  'MIN_Rededge1',
#  'MIN_RGR',
#  'MIN_SB550',
#  'MIN_SR672_708',
#  'MIN_TCI',
#  'MIN_WVP',
#  'MAX_Blue_2000',
#  'MAX_Green_2000',
#  'MAX_Red_2000',
#  'MAX_NIR_2000',
#  'MAX_SWIR1_2000',
#  'MAX_SWIR2_2000',
#  'MAX_TIRS1_2000',
#  'MAX_TIRS2_2000',
#  'MAX_TSAVI_2000',
#  'MAX_Alteration_2000',
#  'MAX_AVI_2000',
#  'MAX_BWDRVI_2000',
#  'MAX_Chlgreen_2000',
#  'MAX_Cigreen_2000',
#  'MAX_Cirededge_2000',
#  'MAX_Chlred_edge_2000',
#  'MAX_CVI_2000',
#  'MAX_CI_2000',
#  'MAX_CTVI_2000',
#  'MAX_CRI550_2000',
#  'MAX_D678_500_2000',
#  'MAX_DVIMSS_2000',
#  'MAX_DSWI_2000',
#  'MAX_DSWI_5_2000',
#  'MAX_EVI_2000',
#  'MAX_Fe3_2000',
#  'MAX_Ferric_Oxides_2000',
#  'MAX_Ferrous_Silicates_2000',
#  'MAX_GEMI_2000',
#  'MAX_GVMI_2000',
#  'MAX_Gossan_2000',
#  'MAX_GARI_2000',
#  'MAX_GLI_2000',
#  'MAX_H_2000',
#  'MAX_IR550_2000',
#  'MAX_mCRIG_2000',
#  'MAX_mCRIRE_2000',
#  'MAX_MVI_2000',
#  'MAX_MCARI1_2000',
#  'MAX_MCARI2_2000',
#  'MAX_NLI_2000',
#  'MAX_NormG_2000',
#  'MAX_NormR_2000',
#  'MAX_PPR_2000',
#  'MAX_PSNDc2_2000',
#  'MAX_RDVI_2000',
#  'MAX_IF_2000',
#  'MAX_SLAVI_2000',
#  'MAX_SIPI2_2000',
#  'MAX_VARIgreen_2000',
#  'MED_Blue_2000',
#  'MED_Green_2000',
#  'MED_Red_2000',
#  'MED_NIR_2000',
#  'MED_SWIR1_2000',
#  'MED_SWIR2_2000',
#  'MED_TIRS1_2000',
#  'MED_TIRS2_2000',
#  'MED_TSAVI_2000',
#  'MED_Alteration_2000',
#  'MED_AVI_2000',
#  'MED_BWDRVI_2000',
#  'MED_Chlgreen_2000',
#  'MED_Cigreen_2000',
#  'MED_Cirededge_2000',
#  'MED_Chlred_edge_2000',
#  'MED_CVI_2000',
#  'MED_CI_2000',
#  'MED_CTVI_2000',
#  'MED_CRI550_2000',
#  'MED_D678_500_2000',
#  'MED_DVIMSS_2000',
#  'MED_DSWI_2000',
#  'MED_DSWI_5_2000',
#  'MED_EVI_2000',
#  'MED_Fe3_2000',
#  'MED_Ferric_Oxides_2000',
#  'MED_Ferrous_Silicates_2000',
#  'MED_GEMI_2000',
#  'MED_GVMI_2000',
#  'MED_Gossan_2000',
#  'MED_GARI_2000',
#  'MED_GLI_2000',
#  'MED_H_2000',
#  'MED_IR550_2000',
#  'MED_mCRIG_2000',
#  'MED_mCRIRE_2000',
#  'MED_MVI_2000',
#  'MED_MCARI1_2000',
#  'MED_MCARI2_2000',
#  'MED_NLI_2000',
#  'MED_NormG_2000',
#  'MED_NormR_2000',
#  'MED_PPR_2000',
#  'MED_PSNDc2_2000',
#  'MED_RDVI_2000',
#  'MED_IF_2000',
#  'MED_SLAVI_2000',
#  'MED_SIPI2_2000',
#  'MED_VARIgreen_2000',
#  'MIN_Blue_2000',
#  'MIN_Green_2000',
#  'MIN_Red_2000',
#  'MIN_NIR_2000',
#  'MIN_SWIR1_2000',
#  'MIN_SWIR2_2000',
#  'MIN_TIRS1_2000',
#  'MIN_TIRS2_2000',
#  'MIN_TSAVI_2000',
#  'MIN_Alteration_2000',
#  'MIN_AVI_2000',
#  'MIN_BWDRVI_2000',
#  'MIN_Chlgreen_2000',
#  'MIN_Cigreen_2000',
#  'MIN_Cirededge_2000',
#  'MIN_Chlred_edge_2000',
#  'MIN_CVI_2000',
#  'MIN_CI_2000',
#  'MIN_CTVI_2000',
#  'MIN_CRI550_2000',
#  'MIN_D678_500_2000',
#  'MIN_DVIMSS_2000',
#  'MIN_DSWI_2000',
#  'MIN_DSWI_5_2000',
#  'MIN_EVI_2000',
#  'MIN_Fe3_2000',
#  'MIN_Ferric_Oxides_2000',
#  'MIN_Ferrous_Silicates_2000',
#  'MIN_GEMI_2000',
#  'MIN_GVMI_2000',
#  'MIN_Gossan_2000',
#  'MIN_GARI_2000',
#  'MIN_GLI_2000',
#  'MIN_H_2000',
#  'MIN_IR550_2000',
#  'MIN_mCRIG_2000',
#  'MIN_mCRIRE_2000',
#  'MIN_MVI_2000',
#  'MIN_MCARI1_2000',
#  'MIN_MCARI2_2000',
#  'MIN_NLI_2000',
#  'MIN_NormG_2000',
#  'MIN_NormR_2000',
#  'MIN_PPR_2000',
#  'MIN_PSNDc2_2000',
#  'MIN_RDVI_2000',
#  'MIN_IF_2000',
#  'MIN_SLAVI_2000',
#  'MIN_SIPI2_2000',
#  'MIN_VARIgreen_2000',
#  'MAX_Blue_2001',
#  'MAX_Green_2001',
#  'MAX_Red_2001',
#  'MAX_NIR_2001',
#  'MAX_SWIR1_2001',
#  'MAX_SWIR2_2001',
#  'MAX_TIRS1_2001',
#  'MAX_TIRS2_2001',
#  'MAX_TSAVI_2001',
#  'MAX_Alteration_2001',
#  'MAX_AVI_2001',
#  'MAX_BWDRVI_2001',
#  'MAX_Chlgreen_2001',
#  'MAX_Cigreen_2001',
#  'MAX_Cirededge_2001',
#  'MAX_Chlred_edge_2001',
#  'MAX_CVI_2001',
#  'MAX_CI_2001',
#  'MAX_CTVI_2001',
#  'MAX_CRI550_2001',
#  'MAX_D678_500_2001',
#  'MAX_DVIMSS_2001',
#  'MAX_DSWI_2001',
#  'MAX_DSWI_5_2001',
#  'MAX_EVI_2001',
#  'MAX_Fe3_2001',
#  'MAX_Ferric_Oxides_2001',
#  'MAX_Ferrous_Silicates_2001',
#  'MAX_GEMI_2001',
#  'MAX_GVMI_2001',
#  'MAX_Gossan_2001',
#  'MAX_GARI_2001',
#  'MAX_GLI_2001',
#  'MAX_H_2001',
#  'MAX_IR550_2001',
#  'MAX_mCRIG_2001',
#  'MAX_mCRIRE_2001',
#  'MAX_MVI_2001',
#  'MAX_MCARI1_2001',
#  'MAX_MCARI2_2001',
#  'MAX_NLI_2001',
#  'MAX_NormG_2001',
#  'MAX_NormR_2001',
#  'MAX_PPR_2001',
#  'MAX_PSNDc2_2001',
#  'MAX_RDVI_2001',
#  'MAX_IF_2001',
#  'MAX_SLAVI_2001',
#  'MAX_SIPI2_2001',
#  'MAX_VARIgreen_2001',
#  'MED_Blue_2001',
#  'MED_Green_2001',
#  'MED_Red_2001',
#  'MED_NIR_2001',
#  'MED_SWIR1_2001',
#  'MED_SWIR2_2001',
#  'MED_TIRS1_2001',
#  'MED_TIRS2_2001',
#  'MED_TSAVI_2001',
#  'MED_Alteration_2001',
#  'MED_AVI_2001',
#  'MED_BWDRVI_2001',
#  'MED_Chlgreen_2001',
#  'MED_Cigreen_2001',
#  'MED_Cirededge_2001',
#  'MED_Chlred_edge_2001',
#  'MED_CVI_2001',
#  'MED_CI_2001',
#  'MED_CTVI_2001',
#  'MED_CRI550_2001',
#  'MED_D678_500_2001',
#  'MED_DVIMSS_2001',
#  'MED_DSWI_2001',
#  'MED_DSWI_5_2001',
#  'MED_EVI_2001',
#  'MED_Fe3_2001',
#  'MED_Ferric_Oxides_2001',
#  'MED_Ferrous_Silicates_2001',
#  'MED_GEMI_2001',
#  'MED_GVMI_2001',
#  'MED_Gossan_2001',
#  'MED_GARI_2001',
#  'MED_GLI_2001',
#  'MED_H_2001',
#  'MED_IR550_2001',
#  'MED_mCRIG_2001',
#  'MED_mCRIRE_2001',
#  'MED_MVI_2001',
#  'MED_MCARI1_2001',
#  'MED_MCARI2_2001',
#  'MED_NLI_2001',
#  'MED_NormG_2001',
#  'MED_NormR_2001',
#  'MED_PPR_2001',
#  'MED_PSNDc2_2001',
#  'MED_RDVI_2001',
#  'MED_IF_2001',
#  'MED_SLAVI_2001',
#  'MED_SIPI2_2001',
#  'MED_VARIgreen_2001',
#  'MIN_Blue_2001',
#  'MIN_Green_2001',
#  'MIN_Red_2001',
#  'MIN_NIR_2001',
#  'MIN_SWIR1_2001',
#  'MIN_SWIR2_2001',
#  'MIN_TIRS1_2001',
#  'MIN_TIRS2_2001',
#  'MIN_TSAVI_2001',
#  'MIN_Alteration_2001',
#  'MIN_AVI_2001',
#  'MIN_BWDRVI_2001',
#  'MIN_Chlgreen_2001',
#  'MIN_Cigreen_2001',
#  'MIN_Cirededge_2001',
#  'MIN_Chlred_edge_2001',
#  'MIN_CVI_2001',
#  'MIN_CI_2001',
#  'MIN_CTVI_2001',
#  'MIN_CRI550_2001',
#  'MIN_D678_500_2001',
#  'MIN_DVIMSS_2001',
#  'MIN_DSWI_2001',
#  'MIN_DSWI_5_2001',
#  'MIN_EVI_2001',
#  'MIN_Fe3_2001',
#  'MIN_Ferric_Oxides_2001',
#  'MIN_Ferrous_Silicates_2001',
#  'MIN_GEMI_2001',
#  'MIN_GVMI_2001',
#  'MIN_Gossan_2001',
#  'MIN_GARI_2001',
#  'MIN_GLI_2001',
#  'MIN_H_2001',
#  'MIN_IR550_2001',
#  'MIN_mCRIG_2001',
#  'MIN_mCRIRE_2001',
#  'MIN_MVI_2001',
#  'MIN_MCARI1_2001',
#  'MIN_MCARI2_2001',
#  'MIN_NLI_2001',
#  'MIN_NormG_2001',
#  'MIN_NormR_2001',
#  'MIN_PPR_2001',
#  'MIN_PSNDc2_2001',
#  'MIN_RDVI_2001',
#  'MIN_IF_2001',
#  'MIN_SLAVI_2001',
#  'MIN_SIPI2_2001',
#  'MIN_VARIgreen_2001',
#  'MAX_Blue_2002',
#  'MAX_Green_2002',
#  'MAX_Red_2002',
#  'MAX_NIR_2002',
#  'MAX_SWIR1_2002',
#  'MAX_SWIR2_2002',
#  'MAX_TIRS1_2002',
#  'MAX_TIRS2_2002',
#  'MAX_TSAVI_2002',
#  'MAX_Alteration_2002',
#  'MAX_AVI_2002',
#  'MAX_BWDRVI_2002',
#  'MAX_Chlgreen_2002',
#  'MAX_Cigreen_2002',
#  'MAX_Cirededge_2002',
#  'MAX_Chlred_edge_2002',
#  'MAX_CVI_2002',
#  'MAX_CI_2002',
#  'MAX_CTVI_2002',
#  'MAX_CRI550_2002',
#  'MAX_D678_500_2002',
#  'MAX_DVIMSS_2002',
#  'MAX_DSWI_2002',
#  'MAX_DSWI_5_2002',
#  'MAX_EVI_2002',
#  'MAX_Fe3_2002',
#  'MAX_Ferric_Oxides_2002',
#  'MAX_Ferrous_Silicates_2002',
#  'MAX_GEMI_2002',
#  'MAX_GVMI_2002',
#  'MAX_Gossan_2002',
#  'MAX_GARI_2002',
#  'MAX_GLI_2002',
#  'MAX_H_2002',
#  'MAX_IR550_2002',
#  'MAX_mCRIG_2002',
#  'MAX_mCRIRE_2002',
#  'MAX_MVI_2002',
#  'MAX_MCARI1_2002',
#  'MAX_MCARI2_2002',
#  'MAX_NLI_2002',
#  'MAX_NormG_2002',
#  'MAX_NormR_2002',
#  'MAX_PPR_2002',
#  'MAX_PSNDc2_2002',
#  'MAX_RDVI_2002',
#  'MAX_IF_2002',
#  'MAX_SLAVI_2002',
#  'MAX_SIPI2_2002',
#  'MAX_VARIgreen_2002',
#  'MED_Blue_2002',
#  'MED_Green_2002',
#  'MED_Red_2002',
#  'MED_NIR_2002',
#  'MED_SWIR1_2002',
#  'MED_SWIR2_2002',
#  'MED_TIRS1_2002',
#  'MED_TIRS2_2002',
#  'MED_TSAVI_2002',
#  'MED_Alteration_2002',
#  'MED_AVI_2002',
#  'MED_BWDRVI_2002',
#  'MED_Chlgreen_2002',
#  'MED_Cigreen_2002',
#  'MED_Cirededge_2002',
#  'MED_Chlred_edge_2002',
#  'MED_CVI_2002',
#  'MED_CI_2002',
#  'MED_CTVI_2002',
#  'MED_CRI550_2002',
#  'MED_D678_500_2002',
#  'MED_DVIMSS_2002',
#  'MED_DSWI_2002',
#  'MED_DSWI_5_2002',
#  'MED_EVI_2002',
#  'MED_Fe3_2002',
#  'MED_Ferric_Oxides_2002',
#  'MED_Ferrous_Silicates_2002',
#  'MED_GEMI_2002',
#  'MED_GVMI_2002',
#  'MED_Gossan_2002',
#  'MED_GARI_2002',
#  'MED_GLI_2002',
#  'MED_H_2002',
#  'MED_IR550_2002',
#  'MED_mCRIG_2002',
#  'MED_mCRIRE_2002',
#  'MED_MVI_2002',
#  'MED_MCARI1_2002',
#  'MED_MCARI2_2002',
#  'MED_NLI_2002',
#  'MED_NormG_2002',
#  'MED_NormR_2002',
#  'MED_PPR_2002',
#  'MED_PSNDc2_2002',
#  'MED_RDVI_2002',
#  'MED_IF_2002',
#  'MED_SLAVI_2002',
#  'MED_SIPI2_2002',
#  'MED_VARIgreen_2002',
#  'MIN_Blue_2002',
#  'MIN_Green_2002',
#  'MIN_Red_2002',
#  'MIN_NIR_2002',
#  'MIN_SWIR1_2002',
#  'MIN_SWIR2_2002',
#  'MIN_TIRS1_2002',
#  'MIN_TIRS2_2002',
#  'MIN_TSAVI_2002',
#  'MIN_Alteration_2002',
#  'MIN_AVI_2002',
#  'MIN_BWDRVI_2002',
#  'MIN_Chlgreen_2002',
#  'MIN_Cigreen_2002',
#  'MIN_Cirededge_2002',
#  'MIN_Chlred_edge_2002',
#  'MIN_CVI_2002',
#  'MIN_CI_2002',
#  'MIN_CTVI_2002',
#  'MIN_CRI550_2002',
#  'MIN_D678_500_2002',
#  'MIN_DVIMSS_2002',
#  'MIN_DSWI_2002',
#  'MIN_DSWI_5_2002',
#  'MIN_EVI_2002',
#  'MIN_Fe3_2002',
#  'MIN_Ferric_Oxides_2002',
#  'MIN_Ferrous_Silicates_2002',
#  'MIN_GEMI_2002',
#  'MIN_GVMI_2002',
#  'MIN_Gossan_2002',
#  'MIN_GARI_2002',
#  'MIN_GLI_2002',
#  'MIN_H_2002',
#  'MIN_IR550_2002',
#  'MIN_mCRIG_2002',
#  'MIN_mCRIRE_2002',
#  'MIN_MVI_2002',
#  'MIN_MCARI1_2002',
#  'MIN_MCARI2_2002',
#  'MIN_NLI_2002',
#  'MIN_NormG_2002',
#  'MIN_NormR_2002',
#  'MIN_PPR_2002',
#  'MIN_PSNDc2_2002',
#  'MIN_RDVI_2002',
#  'MIN_IF_2002',
#  'MIN_SLAVI_2002',
#  'MIN_SIPI2_2002',
#  'MIN_VARIgreen_2002',
#  'MAX_Blue_2003',
#  'MAX_Green_2003',
#  'MAX_Red_2003',
#  'MAX_NIR_2003',
#  'MAX_SWIR1_2003',
#  'MAX_SWIR2_2003',
#  'MAX_TIRS1_2003',
#  'MAX_TIRS2_2003',
#  'MAX_TSAVI_2003',
#  'MAX_Alteration_2003',
#  'MAX_AVI_2003',
#  'MAX_BWDRVI_2003',
#  'MAX_Chlgreen_2003',
#  'MAX_Cigreen_2003',
#  'MAX_Cirededge_2003',
#  'MAX_Chlred_edge_2003',
#  'MAX_CVI_2003',
#  'MAX_CI_2003',
#  'MAX_CTVI_2003',
#  'MAX_CRI550_2003',
#  'MAX_D678_500_2003',
#  'MAX_DVIMSS_2003',
#  'MAX_DSWI_2003',
#  'MAX_DSWI_5_2003',
#  'MAX_EVI_2003',
#  'MAX_Fe3_2003',
#  'MAX_Ferric_Oxides_2003',
#  'MAX_Ferrous_Silicates_2003',
#  'MAX_GEMI_2003',
#  'MAX_GVMI_2003',
#  'MAX_Gossan_2003',
#  'MAX_GARI_2003',
#  'MAX_GLI_2003',
#  'MAX_H_2003',
#  'MAX_IR550_2003',
#  'MAX_mCRIG_2003',
#  'MAX_mCRIRE_2003',
#  'MAX_MVI_2003',
#  'MAX_MCARI1_2003',
#  'MAX_MCARI2_2003',
#  'MAX_NLI_2003',
#  'MAX_NormG_2003',
#  'MAX_NormR_2003',
#  'MAX_PPR_2003',
#  'MAX_PSNDc2_2003',
#  'MAX_RDVI_2003',
#  'MAX_IF_2003',
#  'MAX_SLAVI_2003',
#  'MAX_SIPI2_2003',
#  'MAX_VARIgreen_2003',
#  'MED_Blue_2003',
#  'MED_Green_2003',
#  'MED_Red_2003',
#  'MED_NIR_2003',
#  'MED_SWIR1_2003',
#  'MED_SWIR2_2003',
#  'MED_TIRS1_2003',
#  'MED_TIRS2_2003',
#  'MED_TSAVI_2003',
#  'MED_Alteration_2003',
#  'MED_AVI_2003',
#  'MED_BWDRVI_2003',
#  'MED_Chlgreen_2003',
#  'MED_Cigreen_2003',
#  'MED_Cirededge_2003',
#  'MED_Chlred_edge_2003',
#  'MED_CVI_2003',
#  'MED_CI_2003',
#  'MED_CTVI_2003',
#  'MED_CRI550_2003',
#  'MED_D678_500_2003',
#  'MED_DVIMSS_2003',
#  'MED_DSWI_2003',
#  'MED_DSWI_5_2003',
#  'MED_EVI_2003',
#  'MED_Fe3_2003',
#  'MED_Ferric_Oxides_2003',
#  'MED_Ferrous_Silicates_2003',
#  'MED_GEMI_2003',
#  'MED_GVMI_2003',
#  'MED_Gossan_2003',
#  'MED_GARI_2003',
#  'MED_GLI_2003',
#  'MED_H_2003',
#  'MED_IR550_2003',
#  'MED_mCRIG_2003',
#  'MED_mCRIRE_2003',
#  'MED_MVI_2003',
#  'MED_MCARI1_2003',
#  'MED_MCARI2_2003',
#  'MED_NLI_2003',
#  'MED_NormG_2003',
#  'MED_NormR_2003',
#  'MED_PPR_2003',
#  'MED_PSNDc2_2003',
#  'MED_RDVI_2003',
#  'MED_IF_2003',
#  'MED_SLAVI_2003',
#  'MED_SIPI2_2003',
#  'MED_VARIgreen_2003',
#  'MIN_Blue_2003',
#  'MIN_Green_2003',
#  'MIN_Red_2003',
#  'MIN_NIR_2003',
#  'MIN_SWIR1_2003',
#  'MIN_SWIR2_2003',
#  'MIN_TIRS1_2003',
#  'MIN_TIRS2_2003',
#  'MIN_TSAVI_2003',
#  'MIN_Alteration_2003',
#  'MIN_AVI_2003',
#  'MIN_BWDRVI_2003',
#  'MIN_Chlgreen_2003',
#  'MIN_Cigreen_2003',
#  'MIN_Cirededge_2003',
#  'MIN_Chlred_edge_2003',
#  'MIN_CVI_2003',
#  'MIN_CI_2003',
#  'MIN_CTVI_2003',
#  'MIN_CRI550_2003',
#  'MIN_D678_500_2003',
#  'MIN_DVIMSS_2003',
#  'MIN_DSWI_2003',
#  'MIN_DSWI_5_2003',
#  'MIN_EVI_2003',
#  'MIN_Fe3_2003',
#  'MIN_Ferric_Oxides_2003',
#  'MIN_Ferrous_Silicates_2003',
#  'MIN_GEMI_2003',
#  'MIN_GVMI_2003',
#  'MIN_Gossan_2003',
#  'MIN_GARI_2003',
#  'MIN_GLI_2003',
#  'MIN_H_2003',
#  'MIN_IR550_2003',
#  'MIN_mCRIG_2003',
#  'MIN_mCRIRE_2003',
#  'MIN_MVI_2003',
#  'MIN_MCARI1_2003',
#  'MIN_MCARI2_2003',
#  'MIN_NLI_2003',
#  'MIN_NormG_2003',
#  'MIN_NormR_2003',
#  'MIN_PPR_2003',
#  'MIN_PSNDc2_2003',
#  'MIN_RDVI_2003',
#  'MIN_IF_2003',
#  'MIN_SLAVI_2003',
#  'MIN_SIPI2_2003',
#  'MIN_VARIgreen_2003',
#  'MAX_Blue_2004',
#  'MAX_Green_2004',
#  'MAX_Red_2004',
#  'MAX_NIR_2004',
#  'MAX_SWIR1_2004',
#  'MAX_SWIR2_2004',
#  'MAX_TIRS1_2004',
#  'MAX_TIRS2_2004',
#  'MAX_TSAVI_2004',
#  'MAX_Alteration_2004',
#  'MAX_AVI_2004',
#  'MAX_BWDRVI_2004',
#  'MAX_Chlgreen_2004',
#  'MAX_Cigreen_2004',
#  'MAX_Cirededge_2004',
#  'MAX_Chlred_edge_2004',
#  'MAX_CVI_2004',
#  'MAX_CI_2004',
#  'MAX_CTVI_2004',
#  'MAX_CRI550_2004',
#  'MAX_D678_500_2004',
#  'MAX_DVIMSS_2004',
#  'MAX_DSWI_2004',
#  'MAX_DSWI_5_2004',
#  'MAX_EVI_2004',
#  'MAX_Fe3_2004',
#  'MAX_Ferric_Oxides_2004',
#  'MAX_Ferrous_Silicates_2004',
#  'MAX_GEMI_2004',
#  'MAX_GVMI_2004',
#  'MAX_Gossan_2004',
#  'MAX_GARI_2004',
#  'MAX_GLI_2004',
#  'MAX_H_2004',
#  'MAX_IR550_2004',
#  'MAX_mCRIG_2004',
#  'MAX_mCRIRE_2004',
#  'MAX_MVI_2004',
#  'MAX_MCARI1_2004',
#  'MAX_MCARI2_2004',
#  'MAX_NLI_2004',
#  'MAX_NormG_2004',
#  'MAX_NormR_2004',
#  'MAX_PPR_2004',
#  'MAX_PSNDc2_2004',
#  'MAX_RDVI_2004',
#  'MAX_IF_2004',
#  'MAX_SLAVI_2004',
#  'MAX_SIPI2_2004',
#  'MAX_VARIgreen_2004',
#  'MED_Blue_2004',
#  'MED_Green_2004',
#  'MED_Red_2004',
#  'MED_NIR_2004',
#  'MED_SWIR1_2004',
#  'MED_SWIR2_2004',
#  'MED_TIRS1_2004',
#  'MED_TIRS2_2004',
#  'MED_TSAVI_2004',
#  'MED_Alteration_2004',
#  'MED_AVI_2004',
#  'MED_BWDRVI_2004',
#  'MED_Chlgreen_2004',
#  'MED_Cigreen_2004',
#  'MED_Cirededge_2004',
#  'MED_Chlred_edge_2004',
#  'MED_CVI_2004',
#  'MED_CI_2004',
#  'MED_CTVI_2004',
#  'MED_CRI550_2004',
#  'MED_D678_500_2004',
#  'MED_DVIMSS_2004',
#  'MED_DSWI_2004',
#  'MED_DSWI_5_2004',
#  'MED_EVI_2004',
#  'MED_Fe3_2004',
#  'MED_Ferric_Oxides_2004',
#  'MED_Ferrous_Silicates_2004',
#  'MED_GEMI_2004',
#  'MED_GVMI_2004',
#  'MED_Gossan_2004',
#  'MED_GARI_2004',
#  'MED_GLI_2004',
#  'MED_H_2004',
#  'MED_IR550_2004',
#  'MED_mCRIG_2004',
#  'MED_mCRIRE_2004',
#  'MED_MVI_2004',
#  'MED_MCARI1_2004',
#  'MED_MCARI2_2004',
#  'MED_NLI_2004',
#  ...]
